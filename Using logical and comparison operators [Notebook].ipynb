# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Using logical and comparison operators

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning Objectives
#
# - Understand the concept of logic and comparison operators in SQL.
# - Learn how to use the WHERE clause to filter data based on specific conditions.
# - Understand the use of IN, BETWEEN, and other SQL operators to streamline queries.

# %% [markdown]
# ## Overview
#
# In this notebook, we will explore the use of logic and comparison operators in SQL to filter and extract specific data from a dataset. These operators are essential tools in SQL that allow us to narrow down our data based on certain conditions.
#
# We will be working with the `united_nations.Access_to_Basic_Services` table, which contains information about different countries, their GDP, access to basic services, and more.

# %% [markdown]
# ### Connecting to our MySQL database
#
# Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# load and activate the SQL extension to allows us to execute SQL in a Jupyter notebook

# %load_ext sql

# %%
# establish a connection to the local database using the '%sql' magic command,
# replace 'password' with our connection password and `db_name` with our database name

# %sql mysql+pymysql://root:Maykivu2023@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# ## Exercise
#
# ### Task 1: Basic Filtering with Comparison Operators
#
# You will be working with the `united_nations.Access_to_Basic_Services` table.
# The columns to `SELECT` include
# - `Country_name`
# - `Time_period`
# - `Pct_managed_drinking_water_services`
# - `Pct_managed_sanitation_services`
# - `Est_population_in_millions`
# - and `Est_gdp_in_billions`
#
#
# Use the `WHERE` clause to filter out records of specific countries:
# - `Nigeria`,
# - `Ethiopia`,
# - `Congo`,
# - `Egypt`,
# - `Tanzania`,
# - `Kenya`,
# - and `South Africa`
# - for the time period between `2019` and `2020`.
# Utilize the `OR` operator to include multiple countries in your filter.

# %%
# %%sql
# -- Add your code here
# SELECT
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions
# FROM  Access_to_Basic_Services
#
# WHERE
# (Country_name= 'Nigeria'
# OR Country_name = 'Ethiopia'
# OR Country_name = 'Congo'
# OR Country_name = 'Egypt'
# OR Country_name = 'Tanzania'
# OR Country_name = 'Kenya'
# OR Country_name = 'South Africa')
# AND
# Time_period = 2019 OR Time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 171 rows affected.
# [('Kazakhstan', 2020, Decimal('95.00'), Decimal('98.00'), Decimal('18.755666')),
#  ('Kyrgyzstan', 2020, Decimal('92.67'), Decimal('97.67'), None),
#  ('Tajikistan', 2020, Decimal('85.00'), Decimal('96.33'), Decimal('9.543207')),
#  ('Turkmenistan', 2020, Decimal('100.00'), Decimal('99.33'), Decimal('6.250438')),
#  ('Uzbekistan', 2020, Decimal('98.00'), Decimal('100.00'), Decimal('34.232050')),
#  ('Afghanistan', 2020, Decimal('80.33'), Decimal('54.00'), Decimal('38.972230')),
#  ('Bangladesh', 2020, Decimal('97.67'), Decimal('54.00'), Decimal('167.420951')),
#  ('Bhutan', 2020, Decimal('97.33'), Decimal('76.67'), Decimal('0.772506')),
#  ('India', 2020, Decimal('91.00'), Decimal('72.33'), Decimal('1396.387127')),
#  ('Iran (Islamic Republic of)', 2020, Decimal('96.67'), Decimal('88.33'), None),
#  ('Maldives', 2020, Decimal('99.67'), Decimal('99.33'), Decimal('0.514438')),
#  ('Nepal', 2020, Decimal('90.00'), Decimal('76.67'), Decimal('29.348627')),
#  ('Pakistan', 2020, Decimal('90.67'), Decimal('70.00'), Decimal('227.196741')),
#  ('Sri Lanka', 2020, Decimal('94.33'), Decimal('93.67'), Decimal('21.919000')),
#  ('China', 2020, Decimal('93.67'), Decimal('91.67'), Decimal('1411.100000')),
#  ("Democratic People's Republic of Korea", 2020, Decimal('93.33'), Decimal('83.33'), None),
#  ('Japan', 2020, Decimal('99.00'), Decimal('100.00'), Decimal('126.261000')),
#  ('Mongolia', 2020, Decimal('81.00'), Decimal('65.00'), Decimal('3.294335')),
#  ('Republic of Korea', 2020, Decimal('100.00'), Decimal('100.00'), None),
#  ('Brunei Darussalam', 2020, Decimal('100.00'), None, Decimal('0.441725')),
#  ('Cambodia', 2020, Decimal('75.33'), Decimal('74.33'), Decimal('16.396860')),
#  ('Indonesia', 2020, Decimal('92.00'), Decimal('86.00'), Decimal('271.857970')),
#  ("Lao People's Democratic Republic", 2020, Decimal('86.67'), Decimal('82.00'), None),
#  ('Malaysia', 2020, Decimal('95.33'), Decimal('100.00'), Decimal('33.199993')),
#  ('Myanmar', 2020, Decimal('85.67'), Decimal('74.67'), Decimal('53.423198')),
#  ('Philippines', 2020, Decimal('94.00'), Decimal('82.00'), Decimal('112.190977')),
#  ('Singapore', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('5.685807')),
#  ('Thailand', 2020, Decimal('100.00'), Decimal('98.67'), Decimal('71.475664')),
#  ('Timor-Leste', 2020, Decimal('87.00'), Decimal('60.00'), Decimal('1.299995')),
#  ('Viet Nam', 2020, Decimal('97.33'), Decimal('90.00'), None),
#  ('Bermuda', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('0.063893')),
#  ('Canada', 2020, Decimal('99.00'), Decimal('99.00'), Decimal('38.037204')),
#  ('Greenland', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('0.056367')),
#  ('Saint Pierre and Miquelon', 2020, Decimal('91.00'), Decimal('100.00'), None),
#  ('United States of America', 2020, Decimal('100.00'), Decimal('99.67'), None),
#  ('Barbados', 2020, Decimal('99.00'), Decimal('98.00'), Decimal('0.280693')),
#  ('British Virgin Islands', 2020, Decimal('100.00'), None, Decimal('0.030910')),
#  ('Cuba', 2020, Decimal('96.33'), Decimal('90.00'), Decimal('11.300698')),
#  ('Dominican Republic', 2020, Decimal('95.00'), Decimal('84.33'), Decimal('10.999664')),
#  ('Guadeloupe', 2020, Decimal('100.00'), Decimal('100.00'), None),
#  ('Haiti', 2020, Decimal('65.00'), Decimal('36.00'), Decimal('11.306801')),
#  ('Jamaica', 2020, Decimal('90.33'), Decimal('87.00'), Decimal('2.820436')),
#  ('Martinique', 2020, Decimal('100.00'), Decimal('100.00'), None),
#  ('Montserrat', 2020, Decimal('98.00'), Decimal('89.00'), None),
#  ('Puerto Rico', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('3.281538')),
#  ('Saint Barthélemy', 2020, Decimal('100.00'), Decimal('100.00'), None),
#  ('Saint Lucia', 2020, Decimal('97.00'), Decimal('82.00'), None),
#  ('Saint Martin (French Part)', 2020, Decimal('100.00'), Decimal('100.00'), None),
#  ('Trinidad and Tobago', 2020, Decimal('99.00'), Decimal('94.00'), Decimal('1.518147')),
#  ('United States Virgin Islands', 2020, Decimal('99.00'), Decimal('99.00'), None),
#  ('Belize', 2020, Decimal('98.33'), Decimal('88.67'), Decimal('0.394921')),
#  ('Costa Rica', 2020, Decimal('100.00'), Decimal('97.67'), Decimal('5.123105')),
#  ('El Salvador', 2020, Decimal('97.00'), Decimal('79.67'), Decimal('6.292731')),
#  ('Guatemala', 2020, Decimal('94.00'), Decimal('67.67'), Decimal('16.858333')),
#  ('Honduras', 2020, Decimal('95.33'), Decimal('83.33'), Decimal('10.121763')),
#  ('Mexico', 2020, Decimal('99.33'), Decimal('90.67'), Decimal('125.998302')),
#  ('Nicaragua', 2020, Decimal('79.33'), Decimal('71.67'), Decimal('6.755895')),
#  ('Panama', 2020, Decimal('92.67'), Decimal('81.00'), Decimal('4.294396')),
#  ('Argentina', 2020, Decimal('100.00'), Decimal('99.00'), Decimal('45.376763')),
#  ('Bolivia (Plurinational State of)', 2020, Decimal('90.67'), Decimal('61.67'), None),
#  ('Brazil', 2020, Decimal('98.33'), Decimal('82.33'), Decimal('213.196304')),
#  ('Chile', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('19.300315')),
#  ('Colombia', 2020, Decimal('94.67'), Decimal('91.33'), Decimal('50.930662')),
#  ('Ecuador', 2020, Decimal('94.00'), Decimal('91.33'), Decimal('17.588595')),
#  ('Falkland Islands (Malvinas)', 2020, Decimal('91.00'), Decimal('100.00'), None),
#  ('French Guiana', 2020, Decimal('94.00'), Decimal('92.00'), None),
#  ('Guyana', 2020, Decimal('96.67'), Decimal('87.33'), Decimal('0.797202')),
#  ('Paraguay', 2020, Decimal('99.67'), Decimal('92.00'), Decimal('6.618695')),
#  ('Peru', 2020, Decimal('90.33'), Decimal('74.33'), Decimal('33.304756')),
#  ('Suriname', 2020, Decimal('98.00'), Decimal('88.67'), Decimal('0.607065')),
#  ('Uruguay', 2020, Decimal('98.00'), Decimal('98.33'), Decimal('3.429086')),
#  ('Venezuela (Bolivarian Republic of)', 2020, Decimal('94.00'), Decimal('96.00'), None),
#  ('Algeria', 2020, Decimal('93.33'), Decimal('84.33'), Decimal('43.451666')),
#  ('Egypt', 2019, Decimal('99.33'), Decimal('97.00'), None),
#  ('Egypt', 2020, Decimal('99.33'), Decimal('97.67'), None),
#  ('Libya', 2020, Decimal('100.00'), Decimal('92.00'), Decimal('6.653942')),
#  ('Morocco', 2020, Decimal('88.33'), Decimal('84.67'), Decimal('36.688772')),
#  ('Sudan', 2020, Decimal('62.33'), Decimal('40.33'), Decimal('44.440486')),
#  ('Tunisia', 2020, Decimal('97.00'), Decimal('97.33'), Decimal('12.161723')),
#  ('Armenia', 2020, Decimal('100.00'), Decimal('92.33'), Decimal('2.805608')),
#  ('Azerbaijan', 2020, Decimal('95.67'), Decimal('96.00'), Decimal('10.093121')),
#  ('Bahrain', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('1.477469')),
#  ('Cyprus', 2020, Decimal('100.00'), Decimal('99.33'), Decimal('1.237537')),
#  ('Georgia', 2020, Decimal('96.67'), Decimal('84.33'), Decimal('3.722716')),
#  ('Iraq', 2020, Decimal('97.67'), Decimal('100.00'), Decimal('42.556984')),
#  ('Israel', 2020, Decimal('100.00'), Decimal('99.67'), Decimal('9.215100')),
#  ('Jordan', 2020, Decimal('98.33'), Decimal('96.33'), Decimal('10.928721')),
#  ('Kuwait', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('4.360444')),
#  ('Lebanon', 2020, Decimal('93.00'), Decimal('99.00'), Decimal('5.662923')),
#  ('Oman', 2020, Decimal('87.67'), Decimal('99.00'), Decimal('4.543399')),
#  ('Qatar', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('2.760385')),
#  ('Saudi Arabia', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('35.997107')),
#  ('State of Palestine', 2020, Decimal('98.33'), Decimal('98.67'), None),
#  ('Syrian Arab Republic', 2020, Decimal('93.67'), Decimal('90.00'), Decimal('20.772595')),
#  ('Türkiye', 2020, Decimal('96.67'), Decimal('98.67'), None),
#  ('United Arab Emirates', 2020, Decimal('100.00'), Decimal('99.00'), Decimal('9.287289')),
#  ('Yemen', 2020, Decimal('63.00'), Decimal('57.33'), None),
#  ('Australia', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('25.655289')),
#  ('New Zealand', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('5.090200')),
#  ('Fiji', 2020, Decimal('93.67'), Decimal('99.00'), Decimal('0.920422')),
#  ('New Caledonia', 2020, Decimal('99.00'), Decimal('100.00'), Decimal('0.271130')),
#  ('Papua New Guinea', 2020, Decimal('56.67'), Decimal('27.67'), Decimal('9.749640')),
#  ('Solomon Islands', 2020, Decimal('72.33'), Decimal('44.67'), Decimal('0.691191')),
#  ('Vanuatu', 2020, Decimal('93.00'), Decimal('55.67'), Decimal('0.311685')),
#  ('Guam', 2020, Decimal('100.00'), None, Decimal('0.169231')),
#  ('Kiribati', 2020, Decimal('77.00'), Decimal('45.33'), Decimal('0.126463')),
#  ('Marshall Islands', 2020, Decimal('90.00'), Decimal('78.00'), Decimal('0.043413')),
#  ('Nauru', 2020, Decimal('100.00'), None, Decimal('0.012315')),
#  ('Northern Mariana Islands', 2020, Decimal('100.00'), Decimal('79.00'), Decimal('0.049587')),
#  ('Palau', 2020, Decimal('100.00'), Decimal('99.67'), Decimal('0.017972')),
#  ('American Samoa', 2020, Decimal('100.00'), Decimal('54.00'), Decimal('0.046189')),
#  ('Cook Islands', 2020, Decimal('100.00'), Decimal('99.00'), None),
#  ('French Polynesia', 2020, Decimal('100.00'), Decimal('97.00'), Decimal('0.301920')),
#  ('Niue', 2020, Decimal('97.00'), Decimal('96.00'), None),
#  ('Samoa', 2020, Decimal('92.00'), Decimal('96.33'), Decimal('0.214929')),
#  ('Tokelau', 2020, Decimal('100.00'), Decimal('97.00'), None),
#  ('Tonga', 2020, Decimal('99.00'), Decimal('93.33'), Decimal('0.105254')),
#  ('Tuvalu', 2020, Decimal('100.00'), None, Decimal('0.011069')),
#  ('Wallis and Futuna Islands', 2020, Decimal('99.00'), Decimal('93.00'), None),
#  ('Burundi', 2020, Decimal('70.33'), Decimal('44.33'), Decimal('12.220227')),
#  ('Djibouti', 2020, Decimal('69.00'), Decimal('56.00'), Decimal('1.090156')),
#  ('Ethiopia', 2019, Decimal('57.00'), Decimal('11.67'), Decimal('114.120594')),
#  ('Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('117.190911')),
#  ('Kenya', 2019, Decimal('66.33'), Decimal('33.33'), Decimal('50.951450')),
#  ('Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('51.985780')),
#  ('Madagascar', 2020, Decimal('56.33'), Decimal('13.00'), Decimal('28.225177')),
#  ('Malawi', 2020, Decimal('74.33'), Decimal('28.67'), Decimal('19.377061')),
#  ('Mauritius', 2020, Decimal('100.00'), Decimal('96.00'), Decimal('1.265740')),
#  ('Mayotte', 2020, Decimal('96.00'), Decimal('100.00'), None),
#  ('Mozambique', 2020, Decimal('66.67'), Decimal('40.33'), Decimal('31.178239')),
#  ('Rwanda', 2020, Decimal('66.33'), Decimal('64.00'), Decimal('13.146362')),
#  ('Réunion', 2020, Decimal('100.00'), Decimal('100.00'), None),
#  ('Somalia', 2020, Decimal('57.33'), Decimal('40.00'), Decimal('16.537016')),
#  ('South Sudan', 2020, Decimal('48.33'), Decimal('22.33'), Decimal('10.606227')),
#  ('Uganda', 2020, Decimal('61.00'), Decimal('21.67'), Decimal('44.404611')),
#  ('United Republic of Tanzania', 2020, Decimal('65.00'), Decimal('34.00'), None),
#  ('Zambia', 2020, Decimal('66.67'), Decimal('32.67'), Decimal('18.927715')),
#  ('Zimbabwe', 2020, Decimal('68.00'), Decimal('36.33'), Decimal('15.669666')),
#  ('Angola', 2020, Decimal('52.33'), Decimal('47.00'), Decimal('33.428486')),
#  ('Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), Decimal('26.491087')),
#  ('Central African Republic', 2020, Decimal('38.33'), Decimal('15.00'), Decimal('5.343020')),
#  ('Chad', 2020, Decimal('52.67'), Decimal('18.67'), Decimal('16.644701')),
#  ('Congo', 2019, Decimal('69.00'), Decimal('17.67'), None),
#  ('Congo', 2020, Decimal('69.00'), Decimal('17.67'), None),
#  ('Democratic Republic of the Congo', 2020, Decimal('47.67'), Decimal('15.33'), None),
#  ('Gabon', 2020, Decimal('73.33'), Decimal('47.00'), Decimal('2.292573')),
#  ('Sao Tome and Principe', 2020, Decimal('77.33'), Decimal('46.00'), Decimal('0.218641')),
#  ('Botswana', 2020, Decimal('89.67'), Decimal('74.33'), Decimal('2.546402')),
#  ('Eswatini', 2020, Decimal('76.67'), Decimal('61.33'), Decimal('1.180655')),
#  ('Lesotho', 2020, Decimal('76.33'), Decimal('49.67'), Decimal('2.254100')),
#  ('Namibia', 2020, Decimal('83.67'), Decimal('35.00'), Decimal('2.489098')),
#  ('South Africa', 2019, Decimal('91.67'), Decimal('78.00'), Decimal('58.087055')),
#  ('South Africa', 2020, Decimal('92.00'), Decimal('78.67'), Decimal('58.801927')),
#  ('Benin', 2020, Decimal('65.33'), Decimal('17.33'), Decimal('12.643123')),
#  ('Burkina Faso', 2020, Decimal('53.33'), Decimal('25.00'), Decimal('21.522626')),
#  ('Cabo Verde', 2020, Decimal('87.33'), Decimal('78.00'), Decimal('0.582640')),
#  ("Côte d'Ivoire", 2020, Decimal('70.67'), Decimal('34.67'), None),
#  ('Gambia', 2020, Decimal('79.33'), Decimal('44.33'), None),
#  ('Ghana', 2020, Decimal('84.67'), Decimal('23.00'), Decimal('32.180401')),
#  ('Guinea', 2020, Decimal('67.33'), Decimal('32.33'), Decimal('13.205153')),
#  ('Guinea-Bissau', 2020, Decimal('60.00'), Decimal('19.33'), Decimal('2.015828')),
#  ('Liberia', 2020, Decimal('75.00'), Decimal('17.67'), Decimal('5.087584')),
#  ('Mali', 2020, Decimal('83.67'), Decimal('46.00'), Decimal('21.224040')),
#  ('Mauritania', 2020, Decimal('70.33'), Decimal('48.00'), Decimal('4.498604')),
#  ('Niger', 2020, Decimal('57.33'), Decimal('24.67'), Decimal('24.333639')),
#  ('Nigeria', 2019, Decimal('75.67'), Decimal('41.67'), Decimal('203.304492')),
#  ('Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('208.327405')),
#  ('Saint Helena', 2020, Decimal('99.00'), Decimal('100.00'), None),
#  ('Senegal', 2020, Decimal('85.00'), Decimal('57.00'), Decimal('16.436120')),
#  ('Sierra Leone', 2020, Decimal('65.00'), Decimal('17.33'), Decimal('8.233970')),
#  ('Togo', 2020, Decimal('70.67'), Decimal('20.00'), Decimal('8.442580'))]

# %% [markdown]
# ### Task 2: Streamlining with the IN Operator
#
# Building on the first task, you might have noticed that using multiple `OR` operators can make the query lengthy and a bit complicated. The 'IN' operator offers a more efficient way to achieve the same result.
# The `IN` operator allows you to specify multiple values in a `WHERE` clause, making the query more concise.
# Try to retrieve data for the same list of countries for the same time range, but this time, use the `IN` operator to simplify your query.

# %%
# %%sql
# -- Add your code here
# SELECT
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions
# FROM  Access_to_Basic_Services
#
# WHERE
# Country_name IN ('Nigeria', 'Ethiopia','Congo','Egypt','Tanzania','Kenya','South Africa')
# AND
# Time_period IN (2019,2020);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 12 rows affected.
# [('Egypt', 2019, Decimal('99.33'), Decimal('97.00'), None),
#  ('Egypt', 2020, Decimal('99.33'), Decimal('97.67'), None),
#  ('Ethiopia', 2019, Decimal('57.00'), Decimal('11.67'), Decimal('114.120594')),
#  ('Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('117.190911')),
#  ('Kenya', 2019, Decimal('66.33'), Decimal('33.33'), Decimal('50.951450')),
#  ('Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('51.985780')),
#  ('Congo', 2019, Decimal('69.00'), Decimal('17.67'), None),
#  ('Congo', 2020, Decimal('69.00'), Decimal('17.67'), None),
#  ('South Africa', 2019, Decimal('91.67'), Decimal('78.00'), Decimal('58.087055')),
#  ('South Africa', 2020, Decimal('92.00'), Decimal('78.67'), Decimal('58.801927')),
#  ('Nigeria', 2019, Decimal('75.67'), Decimal('41.67'), Decimal('203.304492')),
#  ('Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('208.327405'))]

# %% [markdown]
# ### Task 3: Combining Multiple Conditions
#
# The `<=` operator is a comparison operator that checks if the value on the left is less than or equal to the value on the right. In this task, you'll use it to filter countries based on specific service percentages.
# You'll continue working with the `united_nations.Access_to_Basic_Services` table.
# The columns to be selected for this task are
# - `Region`,
# - `Country_name`,
# - `Time_period`,
# - `Pct_managed_drinking_water_services`,
# - `Pct_managed_sanitation_services`,
# - `Est_population_in_millions`, and
# - `Est_gdp_in_billions`.
#
# Your goal is to extract data for the year 2020, focusing on countries where less than or equal to 50% of the population has access to sanitation services. This will help identify countries with critical sanitation needs.
# By using the `<=` operator with the `Pct_managed_sanitation_services` column, you can filter out countries that exceed this threshold, leaving only those with the most pressing sanitation challenges.

# %%
# %%sql
# SELECT
#
# Region,
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
#
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# Time_period = 2020 AND
# Pct_managed_sanitation_services <= 50;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 41 rows affected.
# [('Latin America and the Caribbean', 'Haiti', 2020, Decimal('65.00'), Decimal('36.00'), Decimal('11.306801'), Decimal('14.51')),
#  ('Northern Africa and Western Asia', 'Sudan', 2020, Decimal('62.33'), Decimal('40.33'), Decimal('44.440486'), Decimal('27.03')),
#  ('Oceania', 'Papua New Guinea', 2020, Decimal('56.67'), Decimal('27.67'), Decimal('9.749640'), Decimal('23.85')),
#  ('Oceania', 'Solomon Islands', 2020, Decimal('72.33'), Decimal('44.67'), Decimal('0.691191'), Decimal('1.54')),
#  ('Oceania', 'Kiribati', 2020, Decimal('77.00'), Decimal('45.33'), Decimal('0.126463'), Decimal('0.18')),
#  ('Sub-Saharan Africa', 'Burundi', 2020, Decimal('70.33'), Decimal('44.33'), Decimal('12.220227'), Decimal('2.65')),
#  ('Sub-Saharan Africa', 'Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('117.190911'), Decimal('107.66')),
#  ('Sub-Saharan Africa', 'Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('51.985780'), Decimal('100.67')),
#  ('Sub-Saharan Africa', 'Madagascar', 2020, Decimal('56.33'), Decimal('13.00'), Decimal('28.225177'), Decimal('13.05')),
#  ('Sub-Saharan Africa', 'Malawi', 2020, Decimal('74.33'), Decimal('28.67'), Decimal('19.377061'), Decimal('12.18')),
#  ('Sub-Saharan Africa', 'Mozambique', 2020, Decimal('66.67'), Decimal('40.33'), Decimal('31.178239'), Decimal('14.03')),
#  ('Sub-Saharan Africa', 'Somalia', 2020, Decimal('57.33'), Decimal('40.00'), Decimal('16.537016'), Decimal('6.88')),
#  ('Sub-Saharan Africa', 'South Sudan', 2020, Decimal('48.33'), Decimal('22.33'), Decimal('10.606227'), None),
#  ('Sub-Saharan Africa', 'Uganda', 2020, Decimal('61.00'), Decimal('21.67'), Decimal('44.404611'), Decimal('37.60')),
#  ('Sub-Saharan Africa', 'United Republic of Tanzania', 2020, Decimal('65.00'), Decimal('34.00'), None, None),
#  ('Sub-Saharan Africa', 'Zambia', 2020, Decimal('66.67'), Decimal('32.67'), Decimal('18.927715'), Decimal('18.11')),
#  ('Sub-Saharan Africa', 'Zimbabwe', 2020, Decimal('68.00'), Decimal('36.33'), Decimal('15.669666'), Decimal('21.51')),
#  ('Sub-Saharan Africa', 'Angola', 2020, Decimal('52.33'), Decimal('47.00'), Decimal('33.428486'), Decimal('53.62')),
#  ('Sub-Saharan Africa', 'Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), Decimal('26.491087'), Decimal('40.77')),
#  ('Sub-Saharan Africa', 'Central African Republic', 2020, Decimal('38.33'), Decimal('15.00'), Decimal('5.343020'), Decimal('2.33')),
#  ('Sub-Saharan Africa', 'Chad', 2020, Decimal('52.67'), Decimal('18.67'), Decimal('16.644701'), Decimal('10.72')),
#  ('Sub-Saharan Africa', 'Congo', 2020, Decimal('69.00'), Decimal('17.67'), None, None),
#  ('Sub-Saharan Africa', 'Democratic Republic of the Congo', 2020, Decimal('47.67'), Decimal('15.33'), None, None),
#  ('Sub-Saharan Africa', 'Gabon', 2020, Decimal('73.33'), Decimal('47.00'), Decimal('2.292573'), Decimal('15.31')),
#  ('Sub-Saharan Africa', 'Sao Tome and Principe', 2020, Decimal('77.33'), Decimal('46.00'), Decimal('0.218641'), Decimal('0.47')),
#  ('Sub-Saharan Africa', 'Lesotho', 2020, Decimal('76.33'), Decimal('49.67'), Decimal('2.254100'), Decimal('2.23')),
#  ('Sub-Saharan Africa', 'Namibia', 2020, Decimal('83.67'), Decimal('35.00'), Decimal('2.489098'), Decimal('10.58')),
#  ('Sub-Saharan Africa', 'Benin', 2020, Decimal('65.33'), Decimal('17.33'), Decimal('12.643123'), Decimal('15.65')),
#  ('Sub-Saharan Africa', 'Burkina Faso', 2020, Decimal('53.33'), Decimal('25.00'), Decimal('21.522626'), Decimal('17.93')),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", 2020, Decimal('70.67'), Decimal('34.67'), None, None),
#  ('Sub-Saharan Africa', 'Gambia', 2020, Decimal('79.33'), Decimal('44.33'), None, None),
#  ('Sub-Saharan Africa', 'Ghana', 2020, Decimal('84.67'), Decimal('23.00'), Decimal('32.180401'), Decimal('70.04')),
#  ('Sub-Saharan Africa', 'Guinea', 2020, Decimal('67.33'), Decimal('32.33'), Decimal('13.205153'), Decimal('14.18')),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', 2020, Decimal('60.00'), Decimal('19.33'), Decimal('2.015828'), Decimal('1.43')),
#  ('Sub-Saharan Africa', 'Liberia', 2020, Decimal('75.00'), Decimal('17.67'), Decimal('5.087584'), Decimal('3.04')),
#  ('Sub-Saharan Africa', 'Mali', 2020, Decimal('83.67'), Decimal('46.00'), Decimal('21.224040'), Decimal('17.47')),
#  ('Sub-Saharan Africa', 'Mauritania', 2020, Decimal('70.33'), Decimal('48.00'), Decimal('4.498604'), Decimal('8.41')),
#  ('Sub-Saharan Africa', 'Niger', 2020, Decimal('57.33'), Decimal('24.67'), Decimal('24.333639'), Decimal('13.74')),
#  ('Sub-Saharan Africa', 'Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('208.327405'), Decimal('432.20')),
#  ('Sub-Saharan Africa', 'Sierra Leone', 2020, Decimal('65.00'), Decimal('17.33'), Decimal('8.233970'), Decimal('4.06')),
#  ('Sub-Saharan Africa', 'Togo', 2020, Decimal('70.67'), Decimal('20.00'), Decimal('8.442580'), Decimal('7.57'))]

# %% [markdown]
# ## Solutions
#
# ### Task 1: Basic Filtering with Comparison Operators

# %%
# %%sql
# SELECT
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# (Country_name = 'Nigeria'
# OR Country_name = 'Ethiopia'
# OR Country_name = 'Congo'
# OR Country_name = 'Egypt'
# OR Country_name = 'Tanzania'
# OR Country_name = 'Kenya'
# OR Country_name ='South Africa')
# AND Time_period BETWEEN 2019 AND 2020;

# %% [markdown]
# ### Task 2: Streamlining with the IN Operator

# %%
# %%sql
# SELECT
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# Country_name IN (
#         'Nigeria',
#         'Ethiopia' ,
#         'Congo',
#         'Egypt',
#         'Tanzania',
#         'Kenya',
#         'South Africa'
#  )
# AND Time_period BETWEEN 2019 AND 2020;

# %% [markdown]
# ### Task 3: Combining Multiple Conditions

# %%
# %%sql
# SELECT
# Region,
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# Time_period = 2020
# AND Pct_managed_sanitation_services <= 50;

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
